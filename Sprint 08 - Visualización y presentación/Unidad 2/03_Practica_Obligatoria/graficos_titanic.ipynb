# %% [markdown]
# ## Gráfico 1
#
# ![](./graficos_titanic/1_Mortalidad_General.png)

# %% [markdown]
# ## Gráfico 2
#
# ![](./graficos_titanic/2_Supervivencia_Sexo.png)

# %% [markdown]
# ## Gráfico 3
#
# ![](./graficos_titanic/3_Supervivencia_Clase.png)

# %% [markdown]
# ## Gráfico 4
#
# ![](./graficos_titanic/4_Supervivencia_Ninos_Vs_Adultos.png)

# %% [markdown]
# ## Gráficos 5
#
# ![](./graficos_titanic/5_1_Supervivencia_Puerto.png)
# ![](./graficos_titanic/5_2_Distribucion_Clase_Puerto.png)
